# %%
dfres= spark.read.parquet("/mnt/backupaws/metadata/Users_recomendations/*.parquet")

# %%
dfres= dfres.coalesce(1)

# %%
dfres.count()
# Out:
# Out[7]: 2875500

# %%
dfres.write.mode("overwrite").parquet("/mnt/backupaws/metadata/Users_recomendations_2")
